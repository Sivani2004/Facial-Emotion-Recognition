# %% [markdown]
# <a href="https://colab.research.google.com/github/Sivani2004/Facial-Emotion-Recognition/blob/main/Emotion_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install DeepFace
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 37.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.0 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116932 sha256=4cb2955d4156e0c9a3230eb7ef18a9f6fc1370bd42c91ffcbf1fc834ac224189
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# ...

# %%
import cv2
from deepface import DeepFace
img=cv2.imread('content\angry.jpg')
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions=DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  2.08it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 97.5193443871326,
#    'disgust': 5.2940799724857003e-11,
#    'fear': 0.0018509368213872302,
#    'happy': 0.0006811229111225273,
#    'sad': 1.2255421310016952,
#    'surprise': 5.551316610765597e-06,
#    'neutral': 1.252568456969445},
#   'dominant_emotion': 'angry',
#   'region': {'x': 142, 'y': 68, 'w': 160, 'h': 160},
#   'age': 30,
#   'gender': {'Woman': 0.39180973544716835, 'Man': 99.60818886756897},
#   'dominant_gender': 'Man',
#   'race': {'asian': 48.9252895116806,
#    'indian': 3.1127912923693657,
#    'black': 0.5709603894501925,
#    'white': 28.582999110221863,
#    'middle eastern': 4.438893496990204,
#    'latino hispanic': 14.369061589241028},
#   'dominant_race': 'asian'}]

# %%
predictions [0]['dominant_emotion']
# Out:
# 'angry'
